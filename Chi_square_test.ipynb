# %% [markdown]
# # 1.State the Hypotheses
#
# 1.Null Hypothesis (H₀) Definition:
#
# The null hypothesis states that there is no association or relationship between the two categorical variables.
# In this case,there is no association between Device Type (Smart Thermostat vs. Smart Light) and Customer Satisfaction.
# In other words, device type and satisfaction are independent.
#
# 2.Alternative Hypothesis (H₁) Definition:
#
# The alternative hypothesis states that there is an association or relationship between the two categorical variables.
# In this case,there is a significant association between Device Type and Customer Satisfaction.
# In other words, device type and satisfaction are dependent.

# %% [markdown]
# # 2.Compute the Chi-Square Statistic
# The Chi-Square statistic checks whether the difference between Observed and Expected values is large enough to be significant.
#
# We use the formula:
#
# χ² = Σ ((O − E)² / E)
#
# Where:
#
# O = Observed frequency
#
# E = Expected frequency
#
# # Step 1: Write the Observed Table (O)
#
# | Satisfaction     | Thermostat | Light   | Row Total |
# | ---------------- | ---------- | ------- | --------- |
# | Very Satisfied   | 50         | 70      | 120       |
# | Satisfied        | 80         | 100     | 180       |
# | Neutral          | 60         | 90      | 150       |
# | Unsatisfied      | 30         | 50      | 80        |
# | Very Unsatisfied | 20         | 50      | 70        |
# | **Column Total** | **240**    | **360** | **600**   |
#
#
# # Step 2: Calculate Expected Frequencies (E)
#
# Formula:
#
# E = (Row Total × Column Total) / Grand Total
#
# 1. Very Satisfied (Row Total = 120)
#
# Thermostat (Expected):
# E = (120 × 240) / 600
# E = 28800 / 600
# E = 48
#
# Light (Expected):
# E = (120 × 360) / 600
# E = 43200 / 600
# E = 72
#
#
# 2. Satisfied (Row Total = 180)
#
# Thermostat (Expected):
#
# E = (180 × 240) / 600
#
# E = 43200 / 600
#
# E = 72
#
# Light (Expected):
#
# E = (180 × 360) / 600
#
# E = 64800 / 600
#
# E = 108
#
#
# 3. Neutral (Row Total = 150)
#
# Thermostat (Expected):
#
# E = (150 × 240) / 600
#
# E = 36000 / 600
#
# E = 60
#
# Light (Expected):
#
# E = (150 × 360) / 600
#
# E = 54000 / 600
#
# E = 90
#
# 4. Unsatisfied (Row Total = 80)
#
# Thermostat (Expected):
#
# E = (80 × 240) / 600
#
# E = 19200 / 600
#
# E = 32
#
# Light (Expected):
#
# E = (80 × 360) / 600
#
# E = 28800 / 600
#
# E = 48
#
# 5. Very Unsatisfied (Row Total = 70)
#
# Thermostat (Expected):
#
# E = (70 × 240) / 600
#
# E = 16800 / 600
#
# E = 28
#
# Light (Expected):
#
# E = (70 × 360) / 600
#
# E = 25200 / 600
#
# E = 42
#
# EXPECTED FREQUENCY TABLE
#
# | Satisfaction     | Thermostat (Expected) | Light (Expected) |
# | ---------------- | --------------------- | ---------------- |
# | Very Satisfied   | **48**                | **72**           |
# | Satisfied        | **72**                | **108**          |
# | Neutral          | **60**                | **90**           |
# | Unsatisfied      | **32**                | **48**           |
# | Very Unsatisfied | **28**                | **42**           |
#
# # Step 3: Compute (O − E)² / E
# 1. Very Satisfied (Row Total = 120)
#
# Thermostat (O = 50, E = 48)
#
# (O − E)² / E = (50 − 48)² / 48
#
# = 4 / 48
#
# = 0.0833
#
# Light (O = 70, E = 72)
#
# (O − E)² / E = (70 − 72)² / 72
#
# = 4 / 72
#
# = 0.0556
#
# 2. Satisfied (Row Total = 180)
#
# Thermostat (O = 80, E = 72)
#
# (O − E)² / E = (80 − 72)² / 72
#
# = 64 / 72
#
# = 0.8889
#
#
# Light (O = 100, E = 108)
#
# (O − E)² / E = (100 − 108)² / 108
#
# = 64 / 108
#
# = 0.5926
#
# 3. Neutral (Row Total = 150)
#
# Thermostat (O = 60, E = 60)
#
# (O − E)² / E = (60 − 60)² / 60
#
# = 0 / 60
#
# = 0
#
# Light (O = 90, E = 90)
#
# (O − E)² / E = (90 − 90)² / 90
#
# = 0 / 90
#
# = 0
#
# 4. Unsatisfied (Row Total = 80)
#
# Thermostat (O = 30, E = 32)
#
# (O − E)² / E = (30 − 32)² / 32
#
# = 4 / 32
#
# = 0.1250
#
# Light (O = 50, E = 48)
#
# (O − E)² / E = (50 − 48)² / 48
#
# = 4 / 48
#
# = 0.0833
#
# 5. Very Unsatisfied (Row Total = 70)
#
# Thermostat (O = 20, E = 28)
#
# (O − E)² / E = (20 − 28)² / 28
#
# = 64 / 28
#
# = 2.2857
#
# Light (O = 50, E = 42)
#
# (O − E)² / E = (50 − 42)² / 42
#
# = 64 / 42
#
# = 1.5238
#
# # Step 4: Add all values
#
# Sum of all (O − E)² / E gives the Chi-Square Statistic.
#
# Chi-Square Statistic = 0.0833 + 0.0556 + 0.8889 + 0.5926 + 0 + 0 + 0.1250 + 0.0833 + 2.2857 + 1.5238 = 5.6382

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Observed frequency table
observed = np.array([
    [50, 70],   # Very Satisfied
    [80, 100],  # Satisfied
    [60, 90],   # Neutral
    [30, 50],   # Unsatisfied
    [20, 50]    # Very Unsatisfied
])

# Perform Chi-Square Test
chi2_stat, p_value, dof, expected = chi2_contingency(observed)

# Print results
print("Degrees of Freedom:", dof)
print("P-Value:", p_value)
print("\nExpected Frequencies:\n", expected)
print("Chi-Square Statistic:", chi2_stat)
# Out:
# Degrees of Freedom: 4
# P-Value: 0.22784371130697179
#
# Expected Frequencies:
#  [[ 48.  72.]
#  [ 72. 108.]
#  [ 60.  90.]
#  [ 32.  48.]
#  [ 28.  42.]]
# Chi-Square Statistic: 5.638227513227513

# %% [markdown]
# # 3. Determine the Critical Value
# To find the critical value for the Chi-Square test, we use:
#
# Significance level (α) = 0.05
#
# Degrees of Freedom (df) = 4
#
# Formula for Degrees of Freedom:
#
# df=(r−1)(c−1)
#
# Here,Rows = 5, Columns = 2
#
# df=(5−1)(2−1)=4
#
# Using the Chi-Square distribution table:
#
# Look up the critical value for: χ 2 (0.05,4)
#
# Critical Value = 9.488

# %%
from scipy.stats import chi2

alpha = 0.05
dof = 4

critical_value = chi2.ppf(1 - alpha, dof)

print("Critical Value:", critical_value)
# Out:
# Critical Value: 9.487729036781154

# %% [markdown]
# # 4. Make a Decision
# To make a decision, compare the Chi-Square test statistic with the critical value.
#
# Calculated Chi-Square Statistic: 5.6382
#
# Critical Value at α = 0.05 and df = 4: 9.488
#
# Decision Rule:
#
# If 𝜒 2
# calculated >
# 𝜒 2
# critical → Reject the Null Hypothesis (H₀)
#
# If 𝜒 2
# calculated
# ≤
# 𝜒 2
# critical → Fail to Reject the Null Hypothesis (H₀)
#
# Compare:  5.6382 < 9.488
#
# Because the calculated Chi-Square value (5.6382) is less than the critical value (9.488), we fail to reject the null hypothesis.
#
# # Conclusion:
#
# Based on the Chi-Square test, the calculated Chi-Square statistic (5.6382) is less than the critical value (9.488) at the 5% significance level. Therefore, we fail to reject the null hypothesis. This indicates that there is no significant association between Device Type and Customer Satisfaction. In other words, customer satisfaction does not depend on whether the customer purchased a Smart Thermostat or a Smart Light.
